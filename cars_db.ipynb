# %% [markdown]
# # Scope of work
#
# 1) Import all necessary libraries and modules.
# 2) First we need to obtain inforamtion about all available cars from the first main pages.
# 3) Create a SQL database and export there gathered info about cars from the main pages.
# 4) Then we will call module dealers_cars to acquire links to every dealer's list of cars from all main pages.
# 5) Now we will repeat the same procedure as in the 1st step but to the every dealer's cars list.
# 6) Add extracted data to a created SQL database

# %% [markdown]
# ## 1. Imort of libraries and modules

# %%
import src.main_pages as main_pages
from datetime import datetime

# %% [markdown]
# ## 2. Acquring cars' information from the first main pages

# %% [markdown]
# Here we call the 1st module 'parsing' to scrap data from the main pages of the website. Then we store all gathered information about cars into corresponding lists.

# %%
# Link to the main webpage
url = 'https://www.autoscout24.com/lst?atype=C&desc=0&sort=standard&source=homepage_search-mask&ustate=N%2CU'

# %% [markdown]
# The module **main_pages** collects all URLs of the main pages from the website autoscout24.com

# %%
all_pages = main_pages.main(url)
# Out:
# ['https://www.autoscout24.com/lst?atype=C&desc=0&page=1&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=2&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=3&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=4&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=5&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=6&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=7&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=8&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=9&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=10&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=11&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=12&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=13&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=14&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=15&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=16&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=17&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=18&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=19&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU', 'https://www.autoscout24.com/lst?atype=C&desc=0&page=20&search_id=m76u8v3lpc&sort=standard&source=listpage_pagination&ustate=N%2CU']

# %% [markdown]
# With a help of **parsing** module we scrap info about cars from main pages (20).

# %%
start = datetime.now()
cars, characteristics, prices, locations = parsing.cars_info(all_pages)
end = datetime.now()
print('Total time :', end-start)
# Out:
# Total time : 0:00:00.000033

# %% [markdown]
# Here we call the module **marks** in order to extract all existing car marks from the website. Afterwards we will replace
# spaces in marks' names into dashes '-'

# %%
marks_menu = marks.all_marks(url)

# %% [markdown]
# Here we call the module **dataframe** in order to gather all info about cars into one dataframe

# %%
df = dataframe.df_construct(marks_menu, cars, characteristics, prices, locations)

# %%
df

# %% [markdown]
# ## 3. Creating a SQL database and exporting parsed data there from the main pages

# %% [markdown]
# Here we connect to another module **sql_db**. This module connects to a PostgreSQL database *autoscout*. In this database there is a schema *autoscout* which contains the main table *cars*.

# %%
sql_db.connect(df,'replace')

# %% [markdown]
# ## 4. Acquring cars' information from the all the car dealers and storing into a SQL database

# %%
# Here we click on all dealer buttons from the main 20 pages and get URLs
start = datetime.now()
dealers = all_dealers.main(url)
end = datetime.now()
print('Total time :', end - start)

# %%
import all_urls

# %%
# Multithreading

start = datetime.now()
pages = all_urls.main(dealers)
end = datetime.now()
print('Total time :', end - start)

# %%
pages_alt = ['https://www.autoscout24.com/lst?atype=C&cid=24363553&page=1&source=listpage_pagination',
 'https://www.autoscout24.com/lst?atype=C&cid=24363553&page=2&source=listpage_pagination&search_id=gxrsmwbnl8&source=listpage_pagination',
 'https://www.autoscout24.com/lst?atype=C&cid=24363553&page=3&source=listpage_pagination&search_id=gxrsmwbnl8&source=listpage_pagination',
 'https://www.autoscout24.com/lst?atype=C&cid=24363553&page=4&source=listpage_pagination&search_id=gxrsmwbnl8&source=listpage_pagination',
 'https://www.autoscout24.com/lst?atype=C&cid=24363553&page=5&source=listpage_pagination&search_id=gxrsmwbnl8&source=listpage_pagination',
 'https://www.autoscout24.com/lst?atype=C&cid=24363553&page=6&source=listpage_pagination&search_id=gxrsmwbnl8&source=listpage_pagination',
 'https://www.autoscout24.com/lst?atype=C&cid=24872232&page=1&source=listpage_pagination',
 'https://www.autoscout24.com/lst?atype=C&cid=24872232&page=2&source=listpage_pagination&search_id=gxrsmwbnl8&source=listpage_pagination']

# %%
import multi_parse

# %%
start = datetime.now()
multi_parse.main(pages_alt, marks_menu)
end = datetime.now()
print('Total time :', end - start)

# %%
import normal_parse

# %%
start = datetime.now()
normal_parse.main(pages_alt, marks_menu)
end = datetime.now()
print('Total time :', end - start)

# %%
start = datetime.now()

for page in all_pages:
    cars_scraper.parser(page, marks_menu)

end = datetime.now()
print('Total time :', end-start)

# %% [markdown]
# Total time :1:28:41.573803
